# %%
def add_1(x):
    x = x + 1
    return x

# %%
add_1(5)
# Out:
# 6

# %%
x = "lunch is at noon."
def where_for_lunch(x):
    return x + " Let's meet at the cafe. "
print (x)
# Out:
# lunch is at noon.

# %%
def add_1(x):
    return x + 1

# %%
add_1(2)
# Out:
# 3
