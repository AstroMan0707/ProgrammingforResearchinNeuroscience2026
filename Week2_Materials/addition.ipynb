# %%
def add_1(x):
    x = x + 1
    return x

# %%
add_1(6)
# Out:
# 7

# %%
x = "lunch is at noon"
def add_sentence(x):
    return x + "let's meet at the cafe"

# %%
add_sentence(x)
# Out:
# "lunch is at noonlet's meet at the cafe"

# %%
def multiply_3(x):
    x = x*3
    return x

# %%
multiply_3(9)
# Out:
# 27

# %%
x = "hello"
def add_words(x):
    return x + "world"

# %%
add_words(x)
# Out:
# 'helloworld'

# %%
print(f"The value after addition is: {add_1(6)}") #use f string to print string with function
# Out:
# The value after addition is: 7
