# %% [markdown]
# dict : Key:value pair ---> Ex: {"lunch" : "pizza"}

# %%
def addition(x, y):
   z = x + y
   return z 

def subtract(x,y):
   z = x - y
   return z

def multiply (x, y):
   z = x * y
   return z

def divide (x, y):
   z = x / y
   return z

print(addition(1, 2))
print(subtract(1, 2))
print(multiply(1, 2))
print(divide(1,2))
# Out:
# 3
# -1
# 2
# 0.5

# %% [markdown]
# bool True , False

# %% [markdown]
# str '3' - not the number 3, but it's whatever's in quotes

# %%
int: integer: 1 , 2

# %%
float: any numbers with decimal points

# %%
rows are first and columns are second in dataframes. rows are called indexes in coding

# %%
df.iloc gives you whatever is in that row = df.iloc[0], gives you the first row
df.loc gives you whatever is in that row, but you have to do df.loc["1"] aka the name is quotes
iloc is no quotes and numbers
loc is the name in quotes
